# %%
from pytorch3d.vis import plot_scene
from pytorch3d.renderer.cameras import PerspectiveCameras
from pytorch3d.transforms import quaternion_to_matrix
import pandas as pd
import torch

# %%
# load the csv
df = pd.read_csv('output/quats.csv')
df = df.iloc[::10, :]

def quat2rotm(q_vec: list):
    q = torch.Tensor(q_vec) # w, x, y, z # w is real
    m = quaternion_to_matrix(q)
    return m

# %%
focal_length = []
principal_points = []
R = []
T = []

for k in range(len(df)):
    focal_length.append((1., 1.))
    principal_points.append((0., 0.))    
    R.append(quat2rotm(df.iloc[k, :4].values))
    T.append(torch.Tensor([0., 0., k]))

focal_length = torch.Tensor(focal_length)
principal_points = torch.Tensor(principal_points)
R = torch.stack(R)
T = torch.stack(T)

cams = PerspectiveCameras(
    focal_length=focal_length,
    principal_point=principal_points,
    R=R,
    T=T
)

# %%
plot_scene({"COLMAP Reconstruction (using SiLK keypoints)": {"cameras": cams}}, cameras=True)
# Out:
# <div>                            <div id="113fcd50-0f1f-4c28-9f82-b0c42d8a338d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("113fcd50-0f1f-4c28-9f82-b0c42d8a338d")) {                    Plotly.newPlot(                        "113fcd50-0f1f-4c28-9f82-b0c42d8a338d",                        [{"marker":{"size":1},"name":"cameras","x":[-0.30000001192092896,0.0,0.0,0.0,0.30000001192092896,0.30000001192092896,-0.30000001192092896,-0.30000001192092896,0.0,0.30000001192092896,0.30000001192092896,0.0,-0.30000001192092896,0.0,0.0,null,-0.3027748167514801,-0.002781516872346401,-0.0028187930583953857,-0.002781516872346401,0.29721179604530334,0.2974354326725006,-0.30255118012428284,-0.3027748167514801,-0.0066742198541760445,0.29721179604530334,0.2974354326725006,-0.0066742198541760445,-0.30255118012428284,-0.0066742198541760445,-0.0006674216128885746,null,-0.2952131927013397,0.004778931848704815,0.004342238884419203,0.004778931848704815,0.3047710359096527,0.3073911964893341,-0.2925930321216583,-0.2952131927013397,0.008698588237166405,0.3047710359096527,0.3073911964893341,0.008698588237166405,-0.2925930321216583,0.008698588237166405,0.004784223157912493,null,-0.2822403907775879,0.017745882272720337,0.017340566962957382,0.017745882272720337,0.31773221492767334,0.3201640844345093,-0.27980852127075195,-0.2822403907775879,0.023702289909124374,0.31773221492767334,0.3201640844345093,0.023702289909124374,-0.27980852127075195,0.023702289909124374,0.016591602936387062,null,-0.22872014343738556,0.07120683789253235,0.07078070938587189,0.07120683789253235,0.37113380432128906,0.37369054555892944,-0.22616340219974518,-0.22872014343738556,0.08527670800685883,0.37113380432128906,0.37369054555892944,0.08527670800685883,-0.22616340219974518,0.08527670800685883,0.0660894513130188,null,-0.21657271683216095,0.08336994051933289,0.08307450264692307,0.08336994051933289,0.3833126425743103,0.3850852847099304,-0.21480007469654083,-0.21657271683216095,0.0957457572221756,0.3833126425743103,0.3850852847099304,0.0957457572221756,-0.21480007469654083,0.0957457572221756,0.07851152122020721,null,-0.22486741840839386,0.07509759813547134,0.07466411590576172,0.07509759813547134,0.37506258487701416,0.3776634931564331,-0.22226651012897491,-0.22486741840839386,0.08488671481609344,0.37506258487701416,0.3776634931564331,0.08488671481609344,-0.22226651012897491,0.08488671481609344,0.07215370982885361,null,-0.22682544589042664,0.07315188646316528,0.07284097373485565,0.07315188646316528,0.3731292188167572,0.3749947249889374,-0.22495993971824646,-0.22682544589042664,0.08103007078170776,0.3731292188167572,0.3749947249889374,0.08103007078170776,-0.22495993971824646,0.08103007078170776,0.07061191648244858,null,-0.35126373171806335,-0.05127538740634918,-0.05170280113816261,-0.05127538740634918,0.2487129271030426,0.2512774169445038,-0.3486992418766022,-0.35126373171806335,-0.05404665321111679,0.2487129271030426,0.2512774169445038,-0.05404665321111679,-0.3486992418766022,-0.05404665321111679,-0.047966405749320984,null,-0.4044971764087677,-0.10452204942703247,-0.10480140149593353,-0.10452204942703247,0.19545307755470276,0.19712916016578674,-0.4028210937976837,-0.4044971764087677,-0.11109000444412231,0.19545307755470276,0.19712916016578674,-0.11109000444412231,-0.4028210937976837,-0.11109000444412231,-0.09998100250959396,null,-0.4424201250076294,-0.14245598018169403,-0.14271637797355652,-0.14245598018169403,0.15750814974308014,0.15907056629657745,-0.4408577084541321,-0.4424201250076294,-0.1507178395986557,0.15750814974308014,0.15907056629657745,-0.1507178395986557,-0.4408577084541321,-0.1507178395986557,-0.1371532380580902,null,-0.43263617157936096,-0.13266678154468536,-0.13317014276981354,-0.13266678154468536,0.16730257868766785,0.17032268643379211,-0.42961 ...
